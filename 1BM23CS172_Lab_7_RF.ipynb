# %% [markdown]
# <a href="https://colab.research.google.com/github/msshailesh45/ML-Lab/blob/main/1BM23CS172_Lab_7_RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = pd.read_csv("/iris (2).csv")

# Features and target
X = data.drop("species", axis=1)   # assuming target column is named 'species'
y = data["species"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=68
)

# -------------------------------
# 1. Default Random Forest (n_estimators = 10)
# -------------------------------
rf_default = RandomForestClassifier(n_estimators=10, random_state=42)
rf_default.fit(X_train, y_train)

y_pred_default = rf_default.predict(X_test)
default_score = accuracy_score(y_test, y_pred_default)

print("Accuracy with default (10 trees):", default_score)


# -------------------------------
# 2. Hyperparameter tuning (number of trees)
# -------------------------------
best_score = 0
best_n = 0

for n in range(1, 101):   # try 1 to 100 trees
    rf = RandomForestClassifier(n_estimators=n, random_state=42)
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_test)
    score = accuracy_score(y_test, y_pred)

    if score > best_score:
        best_score = score
        best_n = n

print("Best accuracy:", best_score)
print("Best number of trees:", best_n)


from sklearn.metrics import confusion_matrix

# For default model
cm_default = confusion_matrix(y_test, y_pred_default)
print("Confusion Matrix (Default - 10 trees):\n", cm_default)

# For best model (inside loop OR after finding best_n)
rf_best = RandomForestClassifier(n_estimators=best_n, random_state=42)
rf_best.fit(X_train, y_train)

y_pred_best = rf_best.predict(X_test)
cm_best = confusion_matrix(y_test, y_pred_best)

print("\nConfusion Matrix (Best Model):\n", cm_best)
# Out:
# Accuracy with default (10 trees): 0.9666666666666667
# Best accuracy: 1.0
# Best number of trees: 1
# Confusion Matrix (Default - 10 trees):
#  [[ 9  0  0]
#  [ 0  9  0]
#  [ 0  1 11]]
#
# Confusion Matrix (Best Model):
#  [[ 9  0  0]
#  [ 0  9  0]
#  [ 0  0 12]]
